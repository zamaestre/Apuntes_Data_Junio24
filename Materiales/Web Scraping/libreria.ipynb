# %%
import requests as req
from bs4 import BeautifulSoup as bs # este alias es estandar
import pandas as pd

# %%
url = 'https://books.toscrape.com/index.html'
html = req.get(url).content

# %%
soup = bs(html, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <!--[if lt IE 7]>      <html lang="en-us" class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html lang="en-us" class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html lang="en-us" class="no-js lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!--> <html class="no-js" lang="en-us"> <!--<![endif]-->
# <head>
# <title>
#     All products | Books to Scrape - Sandbox
# </title>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="24th Jun 2016 09:29" name="created"/>
# <meta content="" name="description"/>
# <meta content="width=device-width" name="viewport"/>
# <meta content="NOARCHIVE,NOCACHE" name="robots"/>
# <!-- Le HTML5 shim, for IE6-8 support of HTML elements -->
# <!--[if lt IE 9]>
#         <script src="//html5shim.googlecode.com/svn/trunk/html5.js"></script>
#         <![endif]-->
# <link href="static/oscar/favicon.ico" rel="shortcut icon"/>
# ...

# %%
print(soup.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
#
# <!--[if lt IE 7]>      <html lang="en-us" class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html lang="en-us" class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html lang="en-us" class="no-js lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!--> <html class="no-js" lang="en-us"> <!--<![endif]-->
# <head>
# <title>
#     All products | Books to Scrape - Sandbox
# </title>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="24th Jun 2016 09:29" name="created"/>
# <meta content="" name="description"/>
# <meta content="width=device-width" name="viewport"/>
# <meta content="NOARCHIVE,NOCACHE" name="robots"/>
# <!-- Le HTML5 shim, for IE6-8 support of HTML elements -->
# <!--[if lt IE 9]>
#         <script src="//html5shim.googlecode.com/svn/trunk/html5.js"></script>
#         <![endif]-->
# <link href="static/oscar/favicon.ico" rel="shortcut icon"/>
# ...

# %%
# Escrapear informacion de libreria

lista_libreria= []
libreria = soup.find('old', {'class':' row'})

for libro in libreria[ :3]:
    dicc_libros= {}
    titulo = libreria.find_all('a', {'href ': 'catalogue/tipping-the-velvet_999/index.html'})['title']
    dicc_libros[titulo]= titulo
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[129], line 4
#       1 # Escrapear informacion de libreria
#       3 lista_libreria= []
# ----> 4 libreria = soup.find('old', {'class':' row'})
#       6 for libro in libreria[ :3]:
#       7     dicc_libros= {}
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\bs4\element.py:2006, in Tag.find(self, name, attrs, recursive, string, **kwargs)
#    1989 """Look in the children of this PageElement and find the first
#    1990 PageElement that matches the given criteria.
#    1991
#    (...)
#    2003 :rtype: bs4.element.Tag | bs4.element.NavigableString
#    2004 """
#    2005 r = None
# -> 2006 l = self.find_all(name, attrs, recursive, string, 1, _stacklevel=3,
#    2007                   **kwargs)
#    2008 if l:
#    2009     r = l[0]
#
# ...

# %%
libreria = soup.find_all('div', {'class':'container-fluid page'})
libreria
# Out:
# [<div class="container-fluid page">
#  <div class="page_inner">
#  <ul class="breadcrumb">
#  <li>
#  <a href="index.html">Home</a>
#  </li>
#  <li class="active">All products</li>
#  </ul>
#  <div class="row">
#  <aside class="sidebar col-sm-4 col-md-3">
#  <div id="promotions_left">
#  </div>
#  <div class="side_categories">
#  <ul class="nav nav-list">
#  <li>
#  <a href="catalogue/category/books_1/index.html">
#
#                                  Books
#
#                          </a>
#  <ul>
#  <li>
#  <a href="catalogue/category/books/travel_2/index.html">
#
#                                  Travel
#
#                          </a>
#  </li>
#  <li>
#  <a href="catalogue/category/books/mystery_3/index.html">
#
#                                  Mystery
#
#                          </a>
#  </li>
#  <li>
#  <a href="catalogue/category/books/historical-fiction_4/index.html">
#
#                                  Historical Fiction
#
#                          </a>
#  </li>
# ...

# %%
# Buscando el Titulo
titulo = libreria.find('a', {'title': 'A Light in the Attic'}).text.strip()
titulo
# Out:
# 'A Light in the ...'

# %%
url_titulo= "https://books.toscrape.com/catalogue/a-light-in-the-attic_1000/index.html" 
linl_titulo = req.get(url_titulo)
linl_titulo
# Out:
# <Response [200]>

# %%
# Categoria 
categoria = libreria.find()

# %%
# Buscando precio
precio = libreria.find('div', {'class': 'price_color '})['class']
precio
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[124], line 2
#       1 # Buscando precio
# ----> 2 precio = libreria.find('div', {'class': 'price_color '})['class']
#       3 precio
#
# TypeError: 'NoneType' object is not subscriptable

# %%
# Buscando Stock
status_stop= libreria.find('p', { 'class' : 'instock availability'}).text.strip()
status_stop
# Out:
# 'In stock'

# %%
# Out:
# 'catalogue/soumission_998/index.html'

# %%
dicc_libros
